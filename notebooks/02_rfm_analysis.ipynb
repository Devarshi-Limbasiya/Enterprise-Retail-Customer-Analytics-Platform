# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rfm = pd.read_csv('rfm_dataset.csv')
rfm.head()
# Out:
#    customer_key  Recency  Frequency  Monetary
# 0             1    270.0          3      8249
# 1             2     49.0          3      6384
# 2             3    339.0          3      8114
# 3             4    263.0          3      8139
# 4             5    272.0          3      8196

# %%
rfm.describe()
# Out:
#        customer_key       Recency     Frequency      Monetary
# count  18484.000000  18482.000000  18484.000000  18484.000000
# mean    9242.500000    189.335786      1.496375   1588.197901
# std     5336.015523    146.296278      1.101139   2124.157912
# min        1.000000      0.000000      1.000000      2.000000
# 25%     4621.750000     86.000000      1.000000     50.000000
# 50%     9242.500000    168.000000      1.000000    271.500000
# 75%    13863.250000    263.000000      2.000000   2511.000000
# max    18484.000000   1126.000000     28.000000  13294.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(rfm['Recency'])
plt.title('Customer Recency Distribution')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(rfm['Frequency'])
plt.title("Customer Frequency vs Monetary Value")
plt.xlabel("Purchase Frequency")
plt.ylabel("Total Spending")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(rfm['Monetary'])
plt.title('Monetary Distribution')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=rfm,
    x='Frequency',
    y='Monetary'
)
plt.title('Customer Frequency vs Monetary Value')
plt.xlabel('Purchase Frequency')
plt.ylabel('Total Spending')
plt.grid(alpha=0.3)
plt.show()
